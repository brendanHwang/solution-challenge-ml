# %%
from ultralytics import YOLO
# from ultralytics.yolo.v8.detect.predict import DetectionPredictor
import cv2

# model = YOLO('v8m_30_best.pt')
model = YOLO('v8n_20best.torchscript')

model.predict(source=0, show=True, conf=0.5)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.
# Loading v8n_20best.torchscript for TorchScript inference...
#
# 1/1: 0... Success ✅ (inf frames of shape 1920x1080 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 640x640 1 helmet, 200.3ms
# 0: 640x640 1 helmet, 112.5ms
# 0: 640x640 1 helmet, 64.2ms
# 0: 640x640 1 helmet, 72.5ms
# ...
