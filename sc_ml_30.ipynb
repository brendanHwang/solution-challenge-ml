# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="OVX0pbqHlYvhQrtRYkve")
# project = rf.workspace("project-heswb").project("hard-hat-sample-81tt4")
# dataset = project.version(2).download("yolov8")

# %% [markdown]
# https://teang1995.tistory.com/17
# 이거 읽고 재시도!

# %%
# !nvidia-smi

# %%
# pip uninstall torch torchvision torchaudio
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.2.0+cu118
# 11.8
# True

# %%
# pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=30 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=30 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=30 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=30 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %% [markdown]
# v8n, v8s, v8m, v8l

# %% [markdown]
# Image, Instantances, Box, R, mAP50, mAP50-95 순서

# %% [markdown]
# v8m이 v8n보다 성는은 좋지만 추론시간은 약간 많이 걸리지만, 전처리 후처리 시간이 save 되면서 전반적으로 performance가 좋게 나옴

# %% [markdown]
# ## v8s

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8s_30\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:03<00:03,  3.73s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  2.00s/it]
# ...

# %% [markdown]
# ## v8n

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8n_30\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                    all         20         65      0.907      0.563      0.604      0.355
#                   head         20         18      0.819      0.754      0.868      0.465
#                 helmet         20         45      0.901      0.933      0.944        0.6
#                 person         20          2          1          0          0          0
# Speed: 2.5ms preprocess, 21.5ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs\detect\val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## * v8m_30

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8m_30\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#                    all         20         65      0.962      0.581      0.634       0.38
#                   head         20         18      0.933      0.833      0.941      0.601
#                 helmet         20         45      0.952      0.911      0.961      0.538
#                 person         20          2          1          0          0          0
# Speed: 1.7ms preprocess, 25.1ms inference, 0.0ms loss, 6.3ms postprocess per image
# Results saved to runs\detect\val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## v8l

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8l_30\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 43608921 parameters, 0 gradients, 164.8 GFLOPs
#                    all         20         65      0.902       0.51      0.733      0.361
#                   head         20         18      0.788      0.778      0.834      0.527
#                 helmet         20         45      0.919      0.752      0.869      0.505
#                 person         20          2          1          0      0.496     0.0511
# Speed: 1.6ms preprocess, 25.6ms inference, 0.0ms loss, 7.2ms postprocess per image
# Results saved to runs\detect\val5
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...
