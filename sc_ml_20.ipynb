# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="OVX0pbqHlYvhQrtRYkve")
# project = rf.workspace("project-heswb").project("hard-hat-sample-81tt4")
# dataset = project.version(2).download("yolov8")

# %% [markdown]
# https://teang1995.tistory.com/17
# 이거 읽고 재시도!

# %%
# !nvidia-smi
# Out:
# Thu Feb 15 20:13:43 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.23                 Driver Version: 551.23         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   31C    P8             21W /  320W |    1350MiB /  10240MiB |     11%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# pip uninstall torch torchvision torchaudio
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.2.0+cu118
# 11.8
# True

# %%
# pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=20 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=20 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=20 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml epochs=20 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %% [markdown]
# v8n, v8s, v8m, v8l

# %% [markdown]
# Image, Instantances, Box, R, mAP50, mAP50-95 순서

# %% [markdown]
# v8m이 v8n보다 성는은 좋지만 추론시간은 약간 많이 걸리지만, 전처리 후처리 시간이 save 되면서 전반적으로 performance가 좋게 나옴

# %% [markdown]
# ## v8s

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8s_20\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#                    all         20         65      0.898      0.578      0.586      0.358
#                   head         20         18      0.757      0.866      0.823      0.495
#                 helmet         20         45      0.936      0.867      0.935      0.578
#                 person         20          2          1          0          0          0
# Speed: 1.7ms preprocess, 25.0ms inference, 0.0ms loss, 5.2ms postprocess per image
# Results saved to runs\detect\val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## * v8n_20

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8n_20\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                    all         20         65      0.933      0.574      0.626      0.347
#                   head         20         18       0.85      0.833       0.93      0.508
#                 helmet         20         45       0.95      0.889      0.935      0.525
#                 person         20          2          1          0     0.0133     0.0078
# Speed: 3.1ms preprocess, 20.7ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to runs\detect\val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## v8m

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8m_20\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#                    all         20         65      0.575      0.781      0.664      0.389
#                   head         20         18      0.644          1      0.865      0.517
#                 helmet         20         45      0.627      0.844      0.878      0.526
#                 person         20          2      0.455        0.5      0.249      0.124
# Speed: 1.6ms preprocess, 25.3ms inference, 0.0ms loss, 5.8ms postprocess per image
# Results saved to runs\detect\val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## v8l

# %%
# !yolo task=detect mode=val model=D:\computer_vision\runs\detect\train_v8l_20\weights\best.pt data=D:\computer_vision\Hard-Hat-Sample-2\data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 43608921 parameters, 0 gradients, 164.8 GFLOPs
#                    all         20         65      0.902       0.51      0.733      0.361
#                   head         20         18      0.788      0.778      0.834      0.527
#                 helmet         20         45      0.919      0.752      0.869      0.505
#                 person         20          2          1          0      0.496     0.0511
# Speed: 1.7ms preprocess, 26.2ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs\detect\val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\computer_vision\Hard-Hat-Sample-2\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# ...
