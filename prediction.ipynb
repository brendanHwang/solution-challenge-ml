# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="OVX0pbqHlYvhQrtRYkve")
# project = rf.workspace("project-heswb").project("hard-hat-sample-81tt4")
# dataset = project.version(2).download("yolov8")
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.207, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Hard-Hat-Sample-2 in yolov8:: 100%|██████████| 491/491 [00:00<00:00, 7081.76it/s]

# %% [markdown]
# ### test detection(inference) v8m_30 , v8n_20

# %%
# !yolo task=detect mode=predict model=v8n_20best.torchscript source='Hard-Hat-Sample-2/test/images' project='./prediction' name='v8m_30_best_test'
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.11.7 torch-2.1.0 CPU (Apple M1 Pro)
# Loading v8n_20best.torchscript for TorchScript inference...
#
# image 1/10 /Users/hwangdong-ug/Documents/solutoin-challenge/solution-challenge-ml/Hard-Hat-Sample-2/test/images/000008_jpg.rf.07i3fiarVpQ8OHII08vG.jpg: 640x640 2 helmets, 155.5ms
# image 2/10 /Users/hwangdong-ug/Documents/solutoin-challenge/solution-challenge-ml/Hard-Hat-Sample-2/test/images/000011_jpg.rf.VcO5aBIYK5g0MSO1w1w1.jpg: 640x640 1 head, 16 helmets, 98.8ms
# image 3/10 /Users/hwangdong-ug/Documents/solutoin-challenge/solution-challenge-ml/Hard-Hat-Sample-2/test/images/000034_jpg.rf.RBFVKBqJXbMcieIM28U4.jpg: 640x640 1 helmet, 58.2ms
# image 4/10 /Users/hwangdong-ug/Documents/solutoin-challenge/solution-challenge-ml/Hard-Hat-Sample-2/test/images/000047_jpg.rf.kBBXfehmdpTLPXMMHOcs.jpg: 640x640 3 helmets, 61.6ms
# ...

# %%
# !yolo task=detect mode=predict model=v8n_20_best.pt source='Hard-Hat-Sample-2/test/images' project='./prediction' name='v8n_20_best_test'

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('./prediction/v8m_30_best_test5/*.jpg'):
    display(Image(filename=image_path))
    print("\n")

# %%
# import glob
# from IPython.display import Image, display

# for image_path in glob.glob('./prediction/v8n_20_best_test2/*.jpg'):
#     display(Image(filename=image_path))
#     print("\n")
